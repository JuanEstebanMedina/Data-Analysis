# %%
import pandas as pd

df = pd.read_csv(
    "../data/data014_small.csv", encoding="utf-8", sep=",", on_bad_lines="skip"
)
df
# Out:
#         #Fila ID_Paciente                          Nombre Género  Edad  \
# 0           1    7418e23e              José Eduard García      M    15
# 1           2    325338ca            José Wilson González      M    51
# 2           3    368d2df9                    Fredy Flórez      M    56
# 3           4    c3613da1  Fredy Cristian González Torres      M    28
# 4           5    c836bfe5                      Paola Niño      F    31
# ...       ...         ...                             ...    ...   ...
# 99995   99996    cc527342             Edwin Alfonso Muñoz      M    42
# 99996   99997    d9b656fa               Sara Isabel Gómez      F    29
# 99997   99998    34f13151                Alberto Sandoval      M    31
# 99998   99999    7d746608           Yulieth Erika Jiménez      F    29
# 99999  100000    e5dd021c              María María Rivera      F    64
#
#        Peso (kg)  Altura (cm)   IMC Presión Arterial  \
# 0           58.7          147  27.2      125/71 mmHg
# ...

# %%
df_ordenado = df.sort_values(by=["Peso (kg)", "Edad"], ascending=[False, True])
df_ordenado
# Out:
#        #Fila ID_Paciente                    Nombre Género  Edad  Peso (kg)  \
# 13127  13128    b7330421             Germán Rivera      M    15      163.2
# 97938  97939    fb346f3b      Camilo William Pérez      M    38      154.3
# 16763  16764    1e21c700          Álvaro Velásquez      M    16      153.9
# 37631  37632    e4a69251       Óscar Juan Quintero      M    35      153.9
# 34191  34192    d2bb6768  Yeison Barrios Sepúlveda      M    60      152.9
# ...      ...         ...                       ...    ...   ...        ...
# 341      342    13dc74f7            Yadira Herrera      F    15        5.6
# 63329  63330    892dae7f     Patricia María Torres      F    16        5.6
# 81771  81772    e1c2840b       Alba Nancy González      F    41        4.2
# 41990  41991    a61ac540               Luisa Duque      F    15        3.2
# 34913  34914    07a71840             Vanessa Silva      F    38        2.7
#
#        Altura (cm)   IMC Presión Arterial  \
# ...
